# %%
import h5py

FNAME="../../nuosc3d/unittest/h5/i0000.h5"

f = h5py.File(FNAME,'r')
for k1 in f:
    print(f[k1])  

print(f.attrs[''():
    print(i.key())
# Out:
# <HDF5 dataset "t1000": shape (262144,), type "<i4">

# %%
# !ls ${HOME}/nuosc3d/unittest/h5/i0000.h5
# Out:
# /home/jovyan/nuosc3d/unittest/h5/i0000.h5
